# %%
import pandas as pd

# %%
df= pd.read_excel(r"C:\Users\NIDHAL\Desktop\Neuer Ordner (2)\lab-customer-analysis-round-2\files_for_lab\excel_files\marketing_customer_analysis.xlsx")

# %%
df
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 1             1.0  KX64629  California              2228.525238       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df1=pd.read_csv(r"C:\Users\NIDHAL\Desktop\Neuer Ordner (2)\lab-customer-analysis-round-2\files_for_lab\csv_files\marketing_customer_analysis.csv")

# %%
df1
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df.shape
# Out:
# (10910, 26)

# %%
df1.shape
# Out:
# (10910, 26)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
df.rename(columns={'State':'ST'}, inplace=True)

# %%
df1.rename(columns={'State':'ST'}, inplace=True)

# %%
df
# Out:
#        Unnamed: 0 Customer          ST  Customer Lifetime Value Response  \
# 0             0.0  DK49336     Arizona              4809.216960       No
# 1             1.0  KX64629  California              2228.525238       No
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 4             4.0  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905     10905.0  FE99816      Nevada             15563.369440       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10907     10907.0  TL39050     Arizona             23893.304100       No
# 10908     10908.0  WA60547  California             11971.977650       No
# 10909     10909.0  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df1
# Out:
#        Unnamed: 0 Customer          ST  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df._get_numeric_data()
# Out:
#        Unnamed: 0  Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0             0.0              4809.216960  48029.0                  61.0
# 1             1.0              2228.525238      0.0                  64.0
# 2             2.0             14947.917300  22139.0                 100.0
# 3             3.0             22332.439460  49078.0                  97.0
# 4             4.0              9025.067525  23675.0                 117.0
# ...           ...                      ...      ...                   ...
# 10905     10905.0             15563.369440      0.0                 253.0
# 10906     10906.0              5259.444853  61146.0                  65.0
# 10907     10907.0             23893.304100  39837.0                 201.0
# 10908     10908.0             11971.977650  64195.0                 158.0
# 10909     10909.0              6857.519928      0.0                 101.0
#
#        Months Since Last Claim  Months Since Policy Inception  \
# ...

# %%
df1._get_numeric_data()
# Out:
#        Unnamed: 0  Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# ...

# %%
df.select_dtypes(exclude=["number"]).columns
# Out:
# Index(['Customer', 'ST', 'Response', 'Coverage', 'Education',
#        'Effective To Date', 'EmploymentStatus', 'Gender', 'Location Code',
#        'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Vehicle Class', 'Vehicle Size', 'Vehicle Type'],
#       dtype='object')

# %%
df1.select_dtypes(exclude=["number"]).columns
# Out:
# Index(['Customer', 'ST', 'Response', 'Coverage', 'Education',
#        'Effective To Date', 'EmploymentStatus', 'Gender', 'Location Code',
#        'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Vehicle Class', 'Vehicle Size', 'Vehicle Type'],
#       dtype='object')

# %%
df.isnull().values.any()
# Out:
# True

# %%
df1.isnull().values.any()
# Out:
# True

# %%
df.dropna()
# Out:
#        Unnamed: 0 Customer          ST  Customer Lifetime Value Response  \
# 2             2.0  LZ68649  Washington             14947.917300       No
# 3             3.0  XL78013      Oregon             22332.439460      Yes
# 10           10.0  HG93801     Arizona              5154.764074       No
# 13           13.0  KR82385  California              5454.587929       No
# 16           16.0  FH51383  California              5326.677654       No
# ...           ...      ...         ...                      ...      ...
# 10902     10902.0  PP30874  California              3579.023825       No
# 10903     10903.0  SU71163     Arizona              2771.663013       No
# 10904     10904.0  QI63521      Nevada             19228.463620       No
# 10906     10906.0  KX53892      Oregon              5259.444853       No
# 10908     10908.0  WA60547  California             11971.977650       No
#
#        Coverage             Education Effective To Date EmploymentStatus  \
# ...
